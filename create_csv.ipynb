# %%
import pandas as pd

# %%
movies_df = pd.read_csv('./datasets/movies_metadata.csv')
movies_df

# %%
movies_df = movies_df.fillna('0')

# %%
import json

# %%
print(movies_df['belongs_to_collection'].head(10))
# Out:
# 0    {'id': 10194, 'name': 'Toy Story Collection', ...
# 1                                                    0
# 2    {'id': 119050, 'name': 'Grumpy Old Men Collect...
# 3                                                    0
# 4    {'id': 96871, 'name': 'Father of the Bride Col...
# 5                                                    0
# 6                                                    0
# 7                                                    0
# 8                                                    0
# 9    {'id': 645, 'name': 'James Bond Collection', '...
# Name: belongs_to_collection, dtype: object

# %%
import ast
import numpy as np
mc_list = [
    ast.literal_eval(movie_collection)
    if movie_collection != '0'
    else np.nan
    for movie_collection in movies_df["belongs_to_collection"]
]

# %%
mc_list
# Out:
# [{'id': 10194,
#   'name': 'Toy Story Collection',
#   'poster_path': '/7G9915LfUQ2lVfwMEEhDsn3kT4B.jpg',
#   'backdrop_path': '/9FBwqcd9IRruEDUrTdcaafOMKUq.jpg'},
#  nan,
#  {'id': 119050,
#   'name': 'Grumpy Old Men Collection',
#   'poster_path': '/nLvUdqgPgm3F85NMCii9gVFUcet.jpg',
#   'backdrop_path': '/hypTnLot2z8wpFS7qwsQHW1uV8u.jpg'},
#  nan,
#  {'id': 96871,
#   'name': 'Father of the Bride Collection',
#   'poster_path': '/nts4iOmNnq7GNicycMJ9pSAn204.jpg',
#   'backdrop_path': '/7qwE57OVZmMJChBpLEbJEmzUydk.jpg'},
#  nan,
#  nan,
#  nan,
#  nan,
#  {'id': 645,
#   'name': 'James Bond Collection',
#   'poster_path': '/HORpg5CSkmeQlAolx3bKMrKgfi.jpg',
#   'backdrop_path': '/6VcVl48kNKvdXOZfJPdarlUGOsk.jpg'},
#  nan,
#  nan,
#  {'id': 117693,
#   'name': 'Balto Collection',
#   'poster_path': '/w0ZgH6Lgxt2bQYnf1ss74UvYftm.jpg',
#   'backdrop_path': '/9VM5LiJV0bGb1st1KyHA3cVnO2G.jpg'},
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  {'id': 3167,
#   'name': 'Ace Ventura Collection',
#   'poster_path': '/qCxH543pScFed1CycwJ1nVgrkOc.jpg',
#   'backdrop_path': '/bswWgdDsLu0fhWMYUzLF8XgiK4h.jpg'},
#  nan,
#  {'id': 91698,
#   'name': 'Chili Palmer Collection',
#   'poster_path': '/ae3smJDdWrMJ77tDpYOrpo4frKq.jpg',
#   'backdrop_path': '/uWaANGQeoSs5vSP1CWtlkDrkqei.jpg'},
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  {'id': 9435,
#   'name': 'Babe Collection',
#   'poster_path': '/jgnah0k4AumfcZE4HHMJywYHvG6.jpg',
#   'backdrop_path': '/zRWuGdIlkWqXMQcs1t3sPy1XQ6x.jpg'},
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  {'id': 9818,
#   'name': 'Mortal Kombat Collection',
#   'poster_path': '/nauCllomdtyciLCRcVrSJKcJQbn.jpg',
#   'backdrop_path': '/qD3efz57VGNywAN4lTvgz3FHnBb.jpg'},
#  nan,
#  nan,
#  nan,
#  {'id': 136214,
#   'name': 'Pocahontas Collection',
#   'poster_path': '/s4RkDe4AjwyrlltdF6Ui7INlME6.jpg',
#   'backdrop_path': '/qqeOxNmtAW7WXdbrmQftgluvve7.jpg'},
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  {'id': 124935,
#   'name': 'The Lawnmower Man Collection',
#   'poster_path': '/slBKrKBbL1g3KURphhAYIyOOH0G.jpg',
#   'backdrop_path': '/id05z92s8Pwc2wbR9YAKngGqOyP.jpg'},
#  nan,
#  nan,
#  {'id': 43563,
#   'name': 'Friday Collection',
#   'poster_path': '/dWh1Fohgx07AEd4vRUwgIj8BYxD.jpg',
#   'backdrop_path': '/pXszT8ZWGj3fohU9FY0niA0IDEw.jpg'},
#  {'id': 10924,
#   'name': 'From Dusk Till Dawn Collection',
#   'poster_path': '/a156nAy5ZTGXlO5wgfvnF26aaDB.jpg',
#   'backdrop_path': '/oIJQPVy33uxBAu9LMXwjsgHLyxP.jpg'},
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  {'id': 122017,
#   'name': 'Screamers Collection',
#   'poster_path': '/vtCuIaQvK3IyLENmuc73RFm4TU7.jpg',
#   'backdrop_path': None},
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  {'id': 256377,
#   'name': 'The Muppet Collection',
#   'poster_path': '/8Ew8EIdFFurMMYjSbWPu1Hl4vLX.jpg',
#   'backdrop_path': '/1AWd3MM90G47mxtD112gRDxSXY9.jpg'},
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  {'id': 91430,
#   'name': 'The Neverending Story Collection',
#   'poster_path': '/tXuOhgEbXoba7vVIybzGlnycoNq.jpg',
#   'backdrop_path': '/2IqXJIR1i0f6Ngq3A6rjXhQNqFc.jpg'},
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  {'id': 14890,
#   'name': 'Bad Boys Collection',
#   'poster_path': '/tSVbihfvVTCbcm0zXKA7L8R6Y9v.jpg',
#   'backdrop_path': '/yUvBiiC77UY6SyKhfFyLj7DNbfh.jpg'},
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  {'id': 120794,
#   'name': 'Batman Collection',
#   'poster_path': '/adQxUvQW8HXNsvMG5aj71pHh9T.jpg',
#   'backdrop_path': '/9SpZvXLZDGGtFqVDByGqSGI64Kw.jpg'},
#  nan,
#  nan,
#  {'id': 439053,
#   'name': 'Brooklyn Cigar Store Collection',
#   'poster_path': '/bgiPsYjbjbRFmEeUfYlp8ZDBVJJ.jpg',
#   'backdrop_path': '/r4Ov7P8OADcOxfpuDujoJl2Cqry.jpg'},
#  nan,
#  {'id': 8819,
#   'name': 'Casper Collection',
#   'poster_path': '/nWKbJAOFwJlJm24dTovfQuUJOc2.jpg',
#   'backdrop_path': None},
#  nan,
#  nan,
#  nan,
#  nan,
#  {'id': 9649,
#   'name': 'Mexico Trilogy',
#   'poster_path': '/qmPhILSFQKaRyc81mVJWl05tHai.jpg',
#   'backdrop_path': '/6p1OzuIKWnTDfDea7IpB9xra5J.jpg'},
#  nan,
#  {'id': 1570,
#   'name': 'Die Hard Collection',
#   'poster_path': '/dQP1lu4tBtCiAMeCRcuTFpJiM7y.jpg',
#   'backdrop_path': '/5kHVblr87FUScuab1PVSsK692IL.jpg'},
#  {'id': 259398,
#   'name': 'Teenage Apocalypse Trilogy',
#   'poster_path': '/kSLUbpxgcHErkaUc0nB193Nph6Y.jpg',
#   'backdrop_path': '/3pzDZR85GPgdC6b4HwHqzqeEDfB.jpg'},
#  nan,
#  nan,
#  {'id': 9328,
#   'name': 'Free Willy Collection',
#   'poster_path': '/3M2Q9ZDTyFBfi3ohz2gizFmnoL0.jpg',
#   'backdrop_path': '/aef15QAJ8Kxbh8W5zXqJb1f9Vhw.jpg'},
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  {'id': 286162,
#   'name': 'Power Rangers Collection',
#   'poster_path': '/zyHCzQUkgaemgCMEplqAqsp83SA.jpg',
#   'backdrop_path': '/ddGPthtIvNM2f8qBAyxa5GSKskK.jpg'},
#  nan,
#  nan,
#  nan,
#  {'id': 328073,
#   'name': 'Síť (kolekce)',
#   'poster_path': '/k8HvmCUbKHBbTJoe7hJQapQd5Uy.jpg',
#   'backdrop_path': '/5j4HxayNgcAgGStNKqPxM0QNC7V.jpg'},
#  nan,
#  nan,
#  {'id': 9068,
#   'name': 'The Prophecy Collection',
#   'poster_path': '/pU4wvBeirFDNk8rs9tsGZLa7Kyb.jpg',
#   'backdrop_path': None},
#  nan,
#  nan,
#  nan,
#  nan,
#  {'id': 247294,
#   'name': 'Showgirls Collection',
#   'poster_path': '/lXpCjeuKtzkckXkam8sgOaaTOhc.jpg',
#   'backdrop_path': '/nKMLBnDGCPdHipJs0Xk8NzNmLFS.jpg'},
#  {'id': 439053,
#   'name': 'Brooklyn Cigar Store Collection',
#   'poster_path': '/bgiPsYjbjbRFmEeUfYlp8ZDBVJJ.jpg',
#   'backdrop_path': '/r4Ov7P8OADcOxfpuDujoJl2Cqry.jpg'},
#  nan,
#  {'id': 9887,
#   'name': 'Species Collection',
#   'poster_path': '/t5J0JH1L8L7CmtC3sL3K2ybgTbE.jpg',
#   'backdrop_path': '/vnpcoCTZhg1EdEog1kAS0pklx1o.jpg'},
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  {'id': 112399,
#   'name': 'Under Siege Collection',
#   'poster_path': '/5hkZdonGNmoqatnadpDnIgEbrho.jpg',
#   'backdrop_path': '/4Ysa3x4wDwolRpUXBCrig7szGon.jpg'},
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  {'id': 23170,
#   'name': 'Burnt by the Sun Trilogy',
#   'poster_path': '/prqpHdXvfzz8uYwGPaHj62XfJ1H.jpg',
#   'backdrop_path': '/h062iMfHieuKdeujaSZBmdYlgRw.jpg'},
#  nan,
#  {'id': 123800,
#   'name': 'Before... Collection',
#   'poster_path': '/giaxAC74fht0LVQ4WKVoDzLM2Iy.jpg',
#   'backdrop_path': '/wtNugZq8ZzBYwPIh3VoNUJdkBWG.jpg'},
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  {'id': 182813,
#   'name': 'Clerks Collection',
#   'poster_path': '/qEjGvJ9I2ak6ENjdJ23dfjqLkAK.jpg',
#   'backdrop_path': '/6Fjkbh2DVAvVZa3c1HamblAN5Bg.jpg'},
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  {'id': 96665,
#   'name': 'Dumb and Dumber Collection',
#   'poster_path': '/fdB86tl7SKIBWZzm0CbrYjOdE1K.jpg',
#   'backdrop_path': '/saUnj5K6buVafDfLfTozDH2eqdC.jpg'},
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  {'id': 410261,
#   'name': 'A Goofy Movie Collection',
#   'poster_path': '/4AkuuP5ljZMsAhzVnpzIXPSmDoy.jpg',
#   'backdrop_path': '/yiLa63gIb7EGH9BbUWXHwI6PMmx.jpg'},
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  {'id': 217704,
#   'name': 'The Vampire Chronicles',
#   'poster_path': '/1Iop0dywqQeD5Mm7oRVR8vZ8gkj.jpg',
#   'backdrop_path': '/5margBoJC97ZrciVpAUc0PiY6Rc.jpg'},
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  {'id': 10,
#   'name': 'Star Wars Collection',
#   'poster_path': '/ghd5zOQnDaDW1mxO7R5fXXpZMu.jpg',
#   'backdrop_path': '/d8duYyyC9J5T825Hg7grmaabfxQ.jpg'},
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  {'id': 286948,
#   'name': 'Nemesis Collection',
#   'poster_path': '/nKAGlTL97Sp1zIy3f6rGEqjyjGG.jpg',
#   'backdrop_path': None},
#  nan,
#  nan,
#  nan,
#  {'id': 300546,
#   'name': 'Once were Warriors Collection',
#   'poster_path': None,
#   'backdrop_path': None},
#  {'id': 48188,
#   'name': 'Poison Ivy Collection',
#   'poster_path': '/wKFflwLibrLXg7U8hcXnzGyziXz.jpg',
#   'backdrop_path': '/hFktEH1hJsf4kzTnYjJB8rMiJpl.jpg'},
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  {'id': 131,
#   'name': 'Three Colors Collection',
#   'poster_path': '/rVdd23QuT5rHX7lZvuAkRRUkeCZ.jpg',
#   'backdrop_path': '/AeHExfHIl70SZCea907KfEoSkfJ.jpg'},
#  {'id': 131,
#   'name': 'Three Colors Collection',
#   'poster_path': '/rVdd23QuT5rHX7lZvuAkRRUkeCZ.jpg',
#   'backdrop_path': '/AeHExfHIl70SZCea907KfEoSkfJ.jpg'},
#  {'id': 131,
#   'name': 'Three Colors Collection',
#   'poster_path': '/rVdd23QuT5rHX7lZvuAkRRUkeCZ.jpg',
#   'backdrop_path': '/AeHExfHIl70SZCea907KfEoSkfJ.jpg'},
#  nan,
#  nan,
#  nan,
#  nan,
#  {'id': 144200,
#   'name': 'Swan Princess Series',
#   'poster_path': '/3qBPAUFUMOOT9KqUEYXWAKy93Ge.jpg',
#   'backdrop_path': '/wxKt5KHvMYUSLHvyPf2xj64y3dJ.jpg'},
#  nan,
#  nan,
#  nan,
#  {'id': 53159,
#   'name': 'The Santa Clause Collection',
#   'poster_path': '/1h8iA6i2DpPhsHC65nUB2voVnm5.jpg',
#   'backdrop_path': '/jQiwVHJN1rsS4DqhF7hlYZTYCH.jpg'},
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  {'id': 115142,
#   'name': 'Tales from the Crypt Collection',
#   'poster_path': '/mjP1Ktqz3VCyX2akRAIjgxaALwx.jpg',
#   'backdrop_path': '/o9Nll2BovcZ9EDmBBMmnHx99wP4.jpg'},
#  {'id': 115570,
#   'name': 'Star Trek: The Next Generation Collection',
#   'poster_path': '/sddV6vaUC6x37icJS3opIXTXB07.jpg',
#   'backdrop_path': '/r7MMQenUURHhAVHFymtOb8AX4Bm.jpg'},
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  {'id': 3167,
#   'name': 'Ace Ventura Collection',
#   'poster_path': '/qCxH543pScFed1CycwJ1nVgrkOc.jpg',
#   'backdrop_path': '/bswWgdDsLu0fhWMYUzLF8XgiK4h.jpg'},
#  nan,
#  nan,
#  nan,
#  nan,
#  {'id': 192492,
#   'name': 'The Jack Ryan Collection',
#   'poster_path': '/uCuiExsQDyJagov5aVAyw38YEm.jpg',
#   'backdrop_path': '/qYlcVBifq5T4wyWV00a5Awq0kUi.jpg'},
#  nan,
#  nan,
#  nan,
#  {'id': 9436,
#   'name': 'The Crow Collection',
#   'poster_path': '/kfU8OZptlBfR5DL9LNGL301Zmlz.jpg',
#   'backdrop_path': '/6sGKUZfV4g5d2LT4CsG89o0416W.jpg'},
#  nan,
#  {'id': 351684,
#   'name': 'The Flintstones (Live-Action) Collection',
#   'poster_path': '/v70Luw2mGhib4s0Osw7Ux8rQgBt.jpg',
#   'backdrop_path': '/qD0rip0E8EcRcjCPcdu5wUknLZJ.jpg'},
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  {'id': 94032,
#   'name': 'The Lion King Collection',
#   'poster_path': '/oG1heUs503GV6xBnFhgyYTGWm05.jpg',
#   'backdrop_path': '/A9IEaj9cPAwEgFnTmteB70oxgJY.jpg'},
#  nan,
#  {'id': 8581,
#   'name': 'A Nightmare on Elm Street Collection',
#   'poster_path': '/BcgmrOz69AUBRukw5LLGeYsOgo.jpg',
#   'backdrop_path': '/xDScJToK3YDTZmxNqQ0hFTObeXq.jpg'},
#  {'id': 43072,
#   'name': 'The Mask Collection',
#   'poster_path': '/pl2vNt9XlxITTgm8wCQ2Y6ThkpT.jpg',
#   'backdrop_path': '/ucDNm5TJW1ji7kIjnX2SZYm7ATM.jpg'},
#  nan,
#  nan,
#  {'id': 37139,
#   'name': 'Naked Gun Collection',
#   'poster_path': '/qTJ2fbdU2Ru4OGZghQB8MYofkrN.jpg',
#   'backdrop_path': '/jxSnW02zjKtFnXFK2UzcLH8Ced2.jpg'},
#  nan,
#  nan,
#  nan,
#  {'id': 167985,
#   'name': 'Richie Rich Collection',
#   'poster_path': None,
#   'backdrop_path': None},
#  nan,
#  nan,
#  {'id': 43064,
#   'name': 'Speed Collection',
#   'poster_path': '/9poztwq7SXjEETRdWXcJsl58kxV.jpg',
#   'backdrop_path': '/75mSNcKIkfZSjXDgytC8UFe6vBl.jpg'},
#  nan,
#  {'id': 170452,
#   'name': 'Timecop Collection',
#   'poster_path': '/7MzxlFFswI2OB7PifjnyMrrYke5.jpg',
#   'backdrop_path': '/mIqsp7AFmyTYjJ4N9qv3FhAUz60.jpg'},
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  {'id': 261203,
#   'name': 'Street Fighter',
#   'poster_path': '/srmcIOxfqARcnHmgHLVNzzFM2RV.jpg',
#   'backdrop_path': '/u5w0uNoQDqUkmErqMsh4RVVOgyy.jpg'},
#  nan,
#  nan,
#  nan,
#  {'id': 439409,
#   'name': 'Fear Collection',
#   'poster_path': None,
#   'backdrop_path': None},
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  {'id': 8050,
#   'name': 'Highlander Collection',
#   'poster_path': '/mNIXoyFicGseg9NoG3NHKZolKze.jpg',
#   'backdrop_path': '/gY5NPUGGJJdaGPlEM6f2pfHNtit.jpg'},
#  nan,
#  nan,
#  nan,
#  nan,
#  {'id': 11716,
#   'name': 'Addams Family Collection',
#   'poster_path': '/iqAjYCir8x2fc8eeQ2k4qZqOMP1.jpg',
#   'backdrop_path': '/gS5yZLrSJ6uNbsz17xoxf70X2Ws.jpg'},
#  nan,
#  nan,
#  nan,
#  nan,
#  {'id': 162028,
#   'name': 'Stakeout Collection',
#   'poster_path': '/oGai5vrDh7VkuTfsJjO31OcEXQk.jpg',
#   'backdrop_path': None},
#  nan,
#  nan,
#  nan,
#  nan,
#  {'id': 85861,
#   'name': 'Beverly Hills Cop Collection',
#   'poster_path': '/fjKbHh7GpTARbiLj0RF7zc5iD0G.jpg',
#   'backdrop_path': '/lhZQuT76B9YcxZIudXZMhhWCKcl.jpg'},
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  {'id': 150156,
#   'name': 'City Slickers Collection',
#   'poster_path': '/1xHwbqIfBQvxNCkdJwQ5vxFwI5H.jpg',
#   'backdrop_path': '/qv2Bcy963o42k65v0km97G1ceZ4.jpg'},
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  {'id': 252313,
#   'name': 'The Endless Summer Collection',
#   'poster_path': '/zhG3P4ALlXxoFi0CGfcVsR3qmDL.jpg',
#   'backdrop_path': '/rbeqwDmy0yPMxBqA2ELvu08okcn.jpg'},
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  {'id': 9328,
#   'name': 'Free Willy Collection',
#   'poster_path': '/3M2Q9ZDTyFBfi3ohz2gizFmnoL0.jpg',
#   'backdrop_path': '/aef15QAJ8Kxbh8W5zXqJb1f9Vhw.jpg'},
#  nan,
#  {'id': 134011,
#   'name': 'The Fugitive / U.S. Marshals Collection',
#   'poster_path': '/idhUzfuEC24PTYhkWasivjoA3O0.jpg',
#   'backdrop_path': '/9xbrJQoHkTgkXY8oDsTmND0FiEX.jpg'},
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  {'id': 412680,
#   'name': 'Hard Target Collection',
#   'poster_path': '/g7Bc4ik16xOBz21BQOcsxrBL8BO.jpg',
#   'backdrop_path': '/wcBIwQY888HX1QWpnv43lAujoId.jpg'},
#  nan,
#  {'id': 52988,
#   'name': 'Hot Shots! Collection',
#   'poster_path': '/5uzldxeEVqvdaZhE4uCT9TTz9p1.jpg',
#   'backdrop_path': '/iGrRouADMV9MbidImsgRORaV3q.jpg'},
#  nan,
#  nan,
#  nan,
#  {'id': 159600,
#   'name': 'House Party Collection',
#   'poster_path': '/hwaQA1SEoiWsacESz0IMaDQ3vVV.jpg',
#   'backdrop_path': None},
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  {'id': 328,
#   'name': 'Jurassic Park Collection',
#   'poster_path': '/qIm2nHXLpBBdMxi8dvfrnDkBUDh.jpg',
#   'backdrop_path': '/pJjIH9QN0OkHFV9eue6XfRVnPkr.jpg'},
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  {'id': 8580,
#   'name': 'The Karate Kid Collection',
#   'poster_path': '/o6h2F0C5eZOy50Q76fNYzc9mvvw.jpg',
#   'backdrop_path': '/1ok5JGCsDt4Sh3CkFeXh2F2KB7F.jpg'},
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  {'id': 5547,
#   'name': 'RoboCop Collection',
#   'poster_path': '/foJBQb9oEOH0mGh77tXyoxXCfzU.jpg',
#   'backdrop_path': '/azQScQWHpz5puIV4YeCcqgiT9Tn.jpg'},
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  {'id': 462565,
#   'name': 'The Secret Garden Collection',
#   'poster_path': '/zy16gzORcFshGK3oE9W6dhQ8yRZ.jpg',
#   'backdrop_path': '/tpNVr5BikRH4tkNJPbYM6Q9yD1a.jpg'},
#  nan,
#  {'id': 105075,
#   'name': 'The Shadow Collection',
#   'poster_path': '/s3ymS1GDfSYmMKmIdCBMc0fbVni.jpg',
#   'backdrop_path': '/ntIfzZNGz2aHRumYM7P8vqLJv6W.jpg'},
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  {'id': 422837,
#   'name': 'Blade Runner Collection',
#   'poster_path': '/foT46aJ7QPUFDl3CK8ArDl0JaZX.jpg',
#   'backdrop_path': '/57zhlMYblPute6qb8v16ZmGSPVv.jpg'},
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  {'id': 224478,
#   'name': 'The Brady Bunch Collection',
#   'poster_path': '/cXW4na1zatUrsxgsssY8uwJ6A3t.jpg',
#   'backdrop_path': None},
#  {'id': 9888,
#   'name': 'Home Alone Collection',
#   'poster_path': '/zYPsleQJo1n1rBPlecJBRb3iwSO.jpg',
#   'backdrop_path': '/cYS2aWxECESUN2OS3JiLrKMmOko.jpg'},
#  nan,
#  {'id': 86027,
#   'name': 'Aladdin Collection',
#   'poster_path': '/enl57YvMhTAdic6El5rfZppyzq2.jpg',
#   'backdrop_path': '/naeLgo2bt4WKfHF4BTrG6mkmjiY.jpg'},
#  {'id': 528,
#   'name': 'The Terminator Collection',
#   'poster_path': '/vxiKtcxAJxHhlg2H1X8y7zcM3k6.jpg',
#   'backdrop_path': '/cpmbkwSxZnKO69V82A9a34tvk2E.jpg'},
#  nan,
#  nan,
#  {'id': 120794,
#   'name': 'Batman Collection',
#   'poster_path': '/adQxUvQW8HXNsvMG5aj71pHh9T.jpg',
#   'backdrop_path': '/9SpZvXLZDGGtFqVDByGqSGI64Kw.jpg'},
#  {'id': 9743,
#   'name': 'The Hannibal Lecter Anthology',
#   'poster_path': '/aRbyr3KsdmIczGh6VrlvlgQdwMQ.jpg',
#   'backdrop_path': '/npCbvak9UhjPsZB9Oa2k2jsqI7E.jpg'},
#  nan,
#  {'id': 153010,
#   'name': 'Beauty and the Beast Collection',
#   'poster_path': '/mIzZxNAT1GIFaEoPYdJsUKC23Oj.jpg',
#   'backdrop_path': '/obOhJ6VC1IGvlxQYLp1KmjrTbt5.jpg'},
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  {'id': 98580,
#   'name': 'Candyman Collection',
#   'poster_path': '/7yGuKyI0YOBZcOcfwP90WkAbwgD.jpg',
#   'backdrop_path': '/hJjCx4njVdHJobhvr84e5J6MgTw.jpg'},
#  nan,
#  nan,
#  {'id': 43058,
#   'name': 'Homeward Bound Collection',
#   'poster_path': '/4S9WMNUJFzxKOjcoS1mGrKFfygI.jpg',
#   'backdrop_path': None},
#  {'id': 141086,
#   'name': 'Heavy Metal Collection',
#   'poster_path': '/tPzcbhK32OqnYmOccqbRw0eje7a.jpg',
#   'backdrop_path': '/iao9hIahX41T1Lxpa5h62J28rQF.jpg'},
#  {'id': 8917,
#   'name': 'Hellraiser Collection',
#   'poster_path': '/lIK0UgJsA18Z5I1PwpucXzgyF3A.jpg',
#   'backdrop_path': '/uaEUgCqB6lGkvM4Wy5blNwLJdfa.jpg'},
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  {'id': 140910,
#   'name': 'All Dogs Go to Heaven Collection',
#   'poster_path': '/yzuYenLnjAHbTPeu7DLAySbcNGi.jpg',
#   'backdrop_path': '/5JaMQn0PtPWGDIeGV8oqXSvJDKk.jpg'},
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  {'id': 87359,
#   'name': 'Mission: Impossible Collection',
#   'poster_path': '/gwyJPIhCK4Xz2WogeBnhCSQfUek.jpg',
#   'backdrop_path': '/49L0c5utmm0A4BkeDafM9BOhyBT.jpg'},
#  nan,
#  nan,
#  nan,
#  nan,
#  {'id': 169452,
#   'name': 'DragonHeart Collection',
#   'poster_path': '/bZsqwJnO65wlZ3ez7dopUQMYALY.jpg',
#   'backdrop_path': '/hRucBWgzCc7iA9avUE2k5gc7dkj.jpg'},
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  {'id': 36694,
#   'name': 'Bloodsport Collection',
#   'poster_path': '/sTqv7FQalXNVGSpfSJaWek077w9.jpg',
#   'backdrop_path': '/1DXtjAAaK7597GV5MSZH6nn0uqS.jpg'},
#  {'id': 158391,
#   'name': 'The Apu Collection',
#   'poster_path': '/kDZJiqL5bCWsbdw2WFqwQoYLUhj.jpg',
#   'backdrop_path': '/b5zCX85EvJpizJzA2WaQmkd6DN6.jpg'},
#  {'id': 158391,
#   'name': 'The Apu Collection',
#   'poster_path': '/kDZJiqL5bCWsbdw2WFqwQoYLUhj.jpg',
#   'backdrop_path': '/b5zCX85EvJpizJzA2WaQmkd6DN6.jpg'},
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  {'id': 144146,
#   'name': 'Lemmy Caution Collection',
#   'poster_path': '/uhLJqJT2nC0CL4AnC6FNH1AolH5.jpg',
#   'backdrop_path': '/m8ENhvf3ZL295uPZKVzQQE6Wruq.jpg'},
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  {'id': 143766,
#   'name': 'The Substitute Collection',
#   'poster_path': '/hImw5aICI3kqEFARKVBzHkehVWb.jpg',
#   'backdrop_path': None},
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  {'id': 52888,
#   'name': 'The Visitors Collection',
#   'poster_path': '/tqLSEkKYdkFCqsNHP1v9pnr0sl.jpg',
#   'backdrop_path': '/ywYnkeaa7LZBU1bW8zavPwzve4X.jpg'},
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  {'id': 23026,
#   'name': 'Ghost in the Shell Collection',
#   'poster_path': '/xEQVBrAd1hWtwCeK39RQ84CRqB7.jpg',
#   'backdrop_path': '/xt0E8CHXzLxEoiPqrjZMRrM4Izi.jpg'},
#  nan,
#  nan,
#  nan,
#  {'id': 529,
#   'name': 'Wallace & Gromit Collection',
#   'poster_path': '/993pCCMO9g9RQUtNDxQgE1B330H.jpg',
#   'backdrop_path': '/huyrvVKEKa9czUY89fnvaAVAtkX.jpg'},
#  nan,
#  nan,
#  {'id': 116661,
#   'name': 'The Arrival Collection',
#   'poster_path': '/oBBLM2XzrBwjmwWRsPmZ4UuBe7g.jpg',
#   'backdrop_path': '/rEk9ZLfrYXL87CMEddMaYAOwC39.jpg'},
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  {'id': 303969,
#   'name': 'Martin Scorsese’s World Cinema Project, Vol. 1',
#   'poster_path': '/nbR7Hniq5qzkF2ma0VkDXQCUTd5.jpg',
#   'backdrop_path': None},
#  nan,
#  nan,
#  nan,
#  nan,
#  {'id': 424202,
#   'name': 'Trainspotting Collection',
#   'poster_path': '/6W9nyZ3Daq4zHkfTRIzNgWg6ai6.jpg',
#   'backdrop_path': '/rIrAfUd5wjkGoDkecNx1aXjGJLu.jpg'},
#  nan,
#  {'id': 304378,
#   'name': 'Independence Day Collection',
#   'poster_path': '/diCxphvzqas0Tr5eq7tLUzg5M7d.jpg',
#   'backdrop_path': '/p7oqa94XgNGVMazXwR49QfyGgtx.jpg'},
#  nan,
#  nan,
#  {'id': 97456,
#   'name': 'The Hunchback of Notre Dame Collection',
#   'poster_path': '/vX0k6lP6tBi8XHdvNtOvsbNgyxM.jpg',
#   'backdrop_path': '/oAq4tE4fTXfsWz35kyajoWNzHfo.jpg'},
#  nan,
#  nan,
#  nan,
#  nan,
#  {'id': 86028,
#   'name': 'The Nutty Professor Collection',
#   'poster_path': '/a6zC38ID7EyAflo8tsPDP4IE0Mt.jpg',
#   'backdrop_path': '/mW1NQFOSCwwgk03SpcpwiQEL2Lo.jpg'},
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  {'id': 224478,
#   'name': 'The Brady Bunch Collection',
#   'poster_path': '/cXW4na1zatUrsxgsssY8uwJ6A3t.jpg',
#   'backdrop_path': None},
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  {'id': 9436,
#   'name': 'The Crow Collection',
#   'poster_path': '/kfU8OZptlBfR5DL9LNGL301Zmlz.jpg',
#   'backdrop_path': '/6sGKUZfV4g5d2LT4CsG89o0416W.jpg'},
#  nan,
#  nan,
#  {'id': 115142,
#   'name': 'Tales from the Crypt Collection',
#   'poster_path': '/mjP1Ktqz3VCyX2akRAIjgxaALwx.jpg',
#   'backdrop_path': '/o9Nll2BovcZ9EDmBBMmnHx99wP4.jpg'},
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  {'id': 115838,
#   'name': 'Escape From ... Collection',
#   'poster_path': '/8Zih8QGPJNXUuws0fIZmjxjs2Su.jpg',
#   'backdrop_path': '/c9mWaF2oeodriDLqYQr425sasxo.jpg'},
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  {'id': 230,
#   'name': 'The Godfather Collection',
#   'poster_path': '/7SJVjEDoo7xH62TS8stkqRk4Byo.jpg',
#   'backdrop_path': '/3WZTxpgscsmoUk81TuECXdFOD0R.jpg'},
#  nan,
#  {'id': 269098,
#   'name': 'Police Story Collection',
#   'poster_path': '/zF4gP4w1xxM7jDKLjTDK3ixkkms.jpg',
#   'backdrop_path': '/5qbfJzkMAUkFxcVo0dqnTRmpUoh.jpg'},
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  {'id': 269098,
#   'name': 'Police Story Collection',
#   'poster_path': '/zF4gP4w1xxM7jDKLjTDK3ixkkms.jpg',
#   'backdrop_path': '/5qbfJzkMAUkFxcVo0dqnTRmpUoh.jpg'},
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  {'id': 19163,
#   'name': 'The Land Before Time Collection',
#   'poster_path': '/n1bjdBVThBezxR6nEf2dy43sTtV.jpg',
#   'backdrop_path': '/alkvR9vTtuZEmd5ygsayOfxYOMa.jpg'},
#  nan,
#  nan,
#  {'id': 91361,
#   'name': 'Halloween Collection',
#   'poster_path': '/2uqHV6YcD9jEL2WuJYjXiiuRDqd.jpg',
#   'backdrop_path': '/mmxf1sOe2T1sma0tH0TgTdcit1p.jpg'},
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  {'id': 4438,
#   'name': 'The Space Odyssey Series',
#   'poster_path': '/i1WdRtc6aObiwGz5NU8WWPW3r1N.jpg',
#   'backdrop_path': '/15FumSExI9SRoL7QJWZAsA0b10c.jpg'},
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  {'id': 47814,
#   'name': 'The Thin Man Collection',
#   'poster_path': '/ro4YziSxDdrfON4CDHwNXvblCD1.jpg',
#   'backdrop_path': '/2yt8EpI4lobOqyANq9jN6b585zZ.jpg'},
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  {'id': 261590,
#   'name': 'Living Dead Collection',
#   'poster_path': '/mSJ20RTWWgtt3aTyn1iwNZ9fbYl.jpg',
#   'backdrop_path': '/inPPfnJ9Wzc9rg1MpkPm0P3D9rJ.jpg'},
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  {'id': 242765,
#   'name': 'In the Line of Duty Collection',
#   'poster_path': '/5Uy5n3fNaCV6hAVC9ZHXHyLkYG7.jpg',
#   'backdrop_path': None},
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  {'id': 10709,
#   'name': 'The Mighty Ducks Collection',
#   'poster_path': '/aUM5CXRiOu0YgrRZtDZSp997zgr.jpg',
#   'backdrop_path': '/8C8f3UkMgNofmipZ4b42UqdnUYb.jpg'},
#  nan,
#  {'id': 87232,
#   'name': 'The Apple Dumpling Gang Collection',
#   'poster_path': '/vd0szkY491LPcz6pZk9TmQThb3S.jpg',
#   'backdrop_path': None},
#  {'id': 181496,
#   'name': 'Davy Crockett Collection',
#   'poster_path': '/8CuB1HGxpy9C0og8WmpLABe4XSi.jpg',
#   'backdrop_path': None},
#  {'id': 90348,
#   'name': 'Witch Mountain Collection',
#   'poster_path': '/3IggdwQeJvkkfMTKRv9iEpInGnV.jpg',
#   'backdrop_path': '/aXZ0LmSgLT1ZiNWnJ5qKaQHqBiC.jpg'},
#  {'id': 12087,
#   'name': 'Herbie Collection',
#   'poster_path': '/uFvt8t7HlB6BzjiJDU6ea1eI28L.jpg',
#   'backdrop_path': '/hgi9EeU50KFhv9pCDmJyx4VLp5G.jpg'},
#  {'id': 12087,
#   'name': 'Herbie Collection',
#   'poster_path': '/uFvt8t7HlB6BzjiJDU6ea1eI28L.jpg',
#   'backdrop_path': '/hgi9EeU50KFhv9pCDmJyx4VLp5G.jpg'},
#  nan,
#  {'id': 216395,
#   'name': 'Parent Trap Collection',
#   'poster_path': None,
#   'backdrop_path': None},
#  nan,
#  {'id': 43058,
#   'name': 'Homeward Bound Collection',
#   'poster_path': '/4S9WMNUJFzxKOjcoS1mGrKFfygI.jpg',
#   'backdrop_path': None},
#  {'id': 294519,
#   'name': 'The Shaggy Dog Collection',
#   'poster_path': '/qCX60rYHFm8T8ffinuMq0cDM3iI.jpg',
#   'backdrop_path': None},
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  {'id': 55419,
#   'name': 'Cinderella Collection',
#   'poster_path': '/ouN0BQzHKOqK03d9qKXP7JOgQdt.jpg',
#   'backdrop_path': '/yNq1UsclAyXaQGhXVSDoyS9wpFo.jpg'},
#  nan,
#  {'id': 271668,
#   'name': 'Caballeros Collection',
#   'poster_path': '/s3Jf9qBqzts4BOkwXGwUcFxKD4w.jpg',
#   'backdrop_path': None},
#  nan,
#  nan,
#  nan,
#  nan,
#  ...]

# %%
movies_df["belongs_to_collection"][1059:]

# %%
movies_df.columns
# Out:
# Index(['adult', 'belongs_to_collection', 'budget', 'genres', 'homepage', 'id',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'video',
#        'vote_average', 'vote_count'],
#       dtype='object')

# %%
df_collection = pd.DataFrame([item for item in mc_list if isinstance(item, dict)])

# %%
df_collection

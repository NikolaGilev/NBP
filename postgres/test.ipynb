# %%
import pandas as pd
working_dir = "../datasets/movies_db/"
df_credits = pd.read_csv(working_dir + "credits.csv")

# %%
df_credits
# Out:
#                                                     cast  \
# 0      [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1      [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2      [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3      [{'cast_id': 1, 'character': "Savannah 'Vannah...
# 4      [{'cast_id': 1, 'character': 'George Banks', '...
# ...                                                  ...
# 45471  [{'cast_id': 0, 'character': '', 'credit_id': ...
# 45472  [{'cast_id': 1002, 'character': 'Sister Angela...
# 45473  [{'cast_id': 6, 'character': 'Emily Shaw', 'cr...
# 45474  [{'cast_id': 2, 'character': '', 'credit_id': ...
# 45475                                                 []
#
#                                                     crew      id
# 0      [{'credit_id': '52fe4284c3a36847f8024f49', 'de...     862
# 1      [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...    8844
# 2      [{'credit_id': '52fe466a9251416c75077a89', 'de...   15602
# ...

# %%
import json

# %%
# cast_row is a list of jsons represented in a string
all_cast_rows = []
for cast_row in df_credits['cast']:
    # we need to split the string like so
    cast_row_elements = cast_row[1:-1].split("},")
    # we need to add back '}' to the elements we split and ignore the last one
    cast_row_elements = [ds + '}' for ds in data_string[:-1]]
    # we add the last one normaly
    cast_row_elements.append(data_string[-1])

    all_row_elements = []
    for element in cast_row_elements:
        element_fixed = element.replace("'", "\"").replace("None", "null")

        json_element = json.loads(element_fixed)
        all_row_elements.append(json_element)
    all_cast_rows.append(all_row_elements)
all_cast_rows

# %%
from itertools import chain
# add this to the rows --> df_credits['id'][idx]

flattened_cast_list = list(chain(*all_cast_rows))
flattened_cast_list

# %%
df_cast = pd.DataFrame(flattened_cast_list)

# %%
df_cast
# Out:
#         cast_id                character                 credit_id  gender  \
# 0            14            Woody (voice)  52fe4284c3a36847f8024f95       2
# 1            15   Buzz Lightyear (voice)  52fe4284c3a36847f8024f99       2
# 2            16  Mr. Potato Head (voice)  52fe4284c3a36847f8024f9d       2
# 3            17       Slinky Dog (voice)  52fe4284c3a36847f8024fa1       2
# 4            18              Rex (voice)  52fe4284c3a36847f8024fa5       2
# ...         ...                      ...                       ...     ...
# 591183       22              Sid (voice)  52fe4284c3a36847f8024fb1       2
# 591184       23       Mrs. Davis (voice)  52fe4284c3a36847f8024fb5       1
# 591185       24         Sergeant (voice)  52fe4284c3a36847f8024fb9       2
# 591186       25           Hannah (voice)  52fe4284c3a36847f8024fbd       1
# 591187       27     TV Announcer (voice)  52fe4284c3a36847f8024fc5       2
#
# ...
